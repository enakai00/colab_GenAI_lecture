# %% [markdown]
# <a href="https://colab.research.google.com/github/enakai00/colab_GenAI_lecture/blob/main/05_VAE_with_descriminator_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, random
os.environ['PYTHONHASHSEED'] = str(20230629)
random.seed(20230629)

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras import layers, models, losses

from tensorflow.keras.datasets import fashion_mnist

np.random.seed(20230629)
tf.random.set_seed(20230629)

# %%
(train_images, train_labels), _ = fashion_mnist.load_data()
train_images = np.pad(train_images, ((0, 0), (2, 2), (2, 2)), constant_values=0)
train_images = train_images.reshape((len(train_images), 32*32)).astype('float32') / 255
train_labels = tf.keras.utils.to_categorical(train_labels, 10)

# %%
def create_labeled_image(x):
    image, label = x
    return np.append(image, label).tolist()

labeled_images = map(create_labeled_image, zip(train_images, train_labels))
labeled_images = np.array(list(labeled_images)).astype('float32')

# %%
sample_indices = []
labels = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
          'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

for i in range(10):
    for c, (image, label) in enumerate(zip(train_images, train_labels)):
        if np.argmax(label) == i:
            sample_indices.append(c)
            break

fig = plt.figure(figsize=(8, 4))
for i in range(10):
    subplot = fig.add_subplot(2, 5, i+1)
    subplot.set_xticks([])
    subplot.set_yticks([])
    subplot.set_title(labels[i])
    subplot.imshow(labeled_images[sample_indices[i]][:32*32].reshape((32, 32)),
                   vmin=0, vmax=1, cmap=plt.cm.gray_r)

# %%
encoder = models.Sequential()
encoder.add(layers.Reshape((32, 32, 1), name='reshape', input_shape=(32*32,)))
encoder.add(layers.Conv2D(32, (3, 3), strides=2, padding='same',
                        activation='relu', name='conv_filter1')) # (16, 16, 32)
encoder.add(layers.Conv2D(64, (3, 3), strides=2, padding='same',
                        activation='relu', name='conv_filter2')) # (8, 8, 64)
encoder.add(layers.Conv2D(128, (3, 3), strides=2, padding='same',
                        activation='relu', name='conv_filter3')) # (4, 4, 128)
encoder.add(layers.Flatten(name='flatten'))
encoder.add(layers.Dense(4, name='mean_and_log_var'))

encoder.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 32, 32, 1)         0
#
#  conv_filter1 (Conv2D)       (None, 16, 16, 32)        320
#
#  conv_filter2 (Conv2D)       (None, 8, 8, 64)          18496
#
#  conv_filter3 (Conv2D)       (None, 4, 4, 128)         73856
#
#  flatten (Flatten)           (None, 2048)              0
#
#  mean_and_log_var (Dense)    (None, 4)                 8196
#
# =================================================================
# Total params: 100,868
# Trainable params: 100,868
# Non-trainable params: 0
# _________________________________________________________________

# %%
sampler = models.Sequential()
sampler.add(layers.Lambda(
    lambda x: x[:, 0:2] + tf.exp(0.5 * x[:, 2:4]) * K.random_normal(shape=(tf.shape(x)[0], 2)),
    input_shape=(4,), name='sampled_embedding'))

sampler.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sampled_embedding (Lambda)  (None, 2)                 0
#
# =================================================================
# Total params: 0
# Trainable params: 0
# Non-trainable params: 0
# _________________________________________________________________

# %%
decoder = models.Sequential()
decoder.add(layers.Dense(4 * 4 * 128, input_shape=(2, ), name='expand'))
decoder.add(layers.Reshape((4, 4, 128), name='reshape2'))
decoder.add(layers.Conv2DTranspose(64, (3, 3), strides=2, padding='same',
                        activation='relu', name='conv_transpose1')) # (8, 8, 64)
decoder.add(layers.Conv2DTranspose(32, (3, 3), strides=2, padding='same',
                        activation='relu', name='conv_transpose2')) # (16, 16, 32)
decoder.add(layers.Conv2DTranspose(1, (3, 3), strides=2, padding='same',
                        activation='sigmoid', name='conv_transpose3')) # (32, 32, 1)
decoder.add(layers.Flatten(name='flatten'))

decoder.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  expand (Dense)              (None, 2048)              6144
#
#  reshape2 (Reshape)          (None, 4, 4, 128)         0
#
#  conv_transpose1 (Conv2DTran  (None, 8, 8, 64)         73792
#  spose)
#
#  conv_transpose2 (Conv2DTran  (None, 16, 16, 32)       18464
#  spose)
#
#  conv_transpose3 (Conv2DTran  (None, 32, 32, 1)        289
#  spose)
#
#  flatten (Flatten)           (None, 1024)              0
#
# =================================================================
# Total params: 98,689
# Trainable params: 98,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
descriminator = models.Sequential()
descriminator.add(layers.Dense(1024, activation='relu',
                               input_shape=(2, ), name='feedforward1'))
descriminator.add(layers.Dense(512, activation='relu', name='feedforward2'))
descriminator.add(layers.Dense(256, activation='relu', name='feedforward3'))
descriminator.add(layers.Dense(10, activation='softmax', name='softmax'))

descriminator.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  feedforward1 (Dense)        (None, 1024)              3072
#
#  feedforward2 (Dense)        (None, 512)               524800
#
#  feedforward3 (Dense)        (None, 256)               131328
#
#  softmax (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 661,770
# Trainable params: 661,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_input = tf.keras.Input(shape=(32*32,))
model_output = layers.Concatenate(name='prediction_with_mean_log_var')(
    [encoder(model_input), # mean and log_var
     decoder(sampler(encoder(model_input))), # reconstructed image
     descriminator(sampler(encoder(model_input))) # label prediction
    ]
)

model = models.Model(model_input, model_output)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 1024)]       0           []
#
#  sequential (Sequential)        (None, 4)            100868      ['input_1[0][0]',
#                                                                   'input_1[0][0]',
#                                                                   'input_1[0][0]']
#
#  sequential_1 (Sequential)      (None, 2)            0           ['sequential[1][0]',
#                                                                   'sequential[2][0]']
#
#  sequential_2 (Sequential)      (None, 1024)         98689       ['sequential_1[0][0]']
#
#  sequential_3 (Sequential)      (None, 10)           661770      ['sequential_1[1][0]']
#
#  prediction_with_mean_log_var (  (None, 1038)        0           ['sequential[0][0]',
#  Concatenate)                                                     'sequential_2[0][0]',
#                                                                   'sequential_3[0][0]']
#
# ==================================================================================================
# Total params: 861,327
# Trainable params: 861,327
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def custom_loss(y_true, y_pred):
    mean, log_var, image, label_pred = y_pred[:, 0:2], y_pred[:, 2:4], y_pred[:, 4:4+32*32], y_pred[:, 4+32*32:]
    image_true, label_true = y_true[:, :32*32], y_true[:, 32*32:]
    reconstruction_loss = losses.mse(image, image_true)
    descriminator_loss = losses.CategoricalCrossentropy()(label_true, label_pred)
    kl_loss = tf.reduce_mean(tf.reduce_sum(
        -0.5 * (1 + log_var - tf.square(mean) - tf.exp(log_var)), axis=1))
    loss = reconstruction_loss + 0.05 * descriminator_loss + 0.001 * kl_loss
    return loss

# %%
model.compile(optimizer='adam', loss=custom_loss)

# %%
def show_result():
    results = model.predict(train_images[sample_indices], verbose=0)[:, 4:]

    fig = plt.figure(figsize=(16, 2.7))
    for i in range(10):
        subplot = fig.add_subplot(2, 10, i+1)
        subplot.set_xticks([])
        subplot.set_yticks([])
        subplot.imshow(train_images[sample_indices[i]].reshape((32, 32)),
                       vmin=0, vmax=1, cmap=plt.cm.gray_r)

        subplot = fig.add_subplot(2, 10, i+11)
        subplot.set_xticks([])
        subplot.set_yticks([])
        subplot.imshow(results[i][:32*32].reshape((32, 32)),
                       vmin=0, vmax=1, cmap=plt.cm.gray_r)

# %%
history = model.fit(train_images[:30000], labeled_images[:30000],
                    batch_size=100, epochs=1)
show_result()
# Out:
# 300/300 [==============================] - 11s 9ms/step - loss: 0.1169

# %%
history = model.fit(train_images, labeled_images,
                    batch_size=100, epochs=50)
show_result()
# Out:
# Epoch 1/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0682
# Epoch 2/50
# 600/600 [==============================] - 6s 9ms/step - loss: 0.0615
# Epoch 3/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0580
# Epoch 4/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0563
# Epoch 5/50
# 600/600 [==============================] - 5s 9ms/step - loss: 0.0545
# Epoch 6/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0535
# Epoch 7/50
# 600/600 [==============================] - 6s 9ms/step - loss: 0.0522
# Epoch 8/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0511
# Epoch 9/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0505
# Epoch 10/50
# 600/600 [==============================] - 6s 9ms/step - loss: 0.0496
# Epoch 11/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0489
# Epoch 12/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0485
# Epoch 13/50
# 600/600 [==============================] - 7s 11ms/step - loss: 0.0477
# Epoch 14/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0469
# Epoch 15/50
# 600/600 [==============================] - 6s 9ms/step - loss: 0.0463
# Epoch 16/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0460
# Epoch 17/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0455
# Epoch 18/50
# 600/600 [==============================] - 5s 9ms/step - loss: 0.0451
# Epoch 19/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0445
# Epoch 20/50
# 600/600 [==============================] - 5s 9ms/step - loss: 0.0443
# Epoch 21/50
# 600/600 [==============================] - 5s 9ms/step - loss: 0.0437
# Epoch 22/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0435
# Epoch 23/50
# 600/600 [==============================] - 6s 9ms/step - loss: 0.0431
# Epoch 24/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0425
# Epoch 25/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0424
# Epoch 26/50
# 600/600 [==============================] - 6s 9ms/step - loss: 0.0420
# Epoch 27/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0417
# Epoch 28/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0416
# Epoch 29/50
# 600/600 [==============================] - 7s 11ms/step - loss: 0.0412
# Epoch 30/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0410
# Epoch 31/50
# 600/600 [==============================] - 6s 9ms/step - loss: 0.0409
# Epoch 32/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0406
# Epoch 33/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0403
# Epoch 34/50
# 600/600 [==============================] - 6s 10ms/step - loss: 0.0402
# Epoch 35/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0400
# Epoch 36/50
# 600/600 [==============================] - 5s 9ms/step - loss: 0.0398
# Epoch 37/50
# 600/600 [==============================] - 5s 9ms/step - loss: 0.0398
# Epoch 38/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0394
# Epoch 39/50
# 600/600 [==============================] - 5s 9ms/step - loss: 0.0392
# Epoch 40/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0392
# Epoch 41/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0391
# Epoch 42/50
# 600/600 [==============================] - 6s 9ms/step - loss: 0.0389
# Epoch 43/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0389
# Epoch 44/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0385
# Epoch 45/50
# 600/600 [==============================] - 5s 9ms/step - loss: 0.0385
# Epoch 46/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0384
# Epoch 47/50
# 600/600 [==============================] - 5s 9ms/step - loss: 0.0383
# Epoch 48/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0380
# Epoch 49/50
# 600/600 [==============================] - 5s 8ms/step - loss: 0.0382
# Epoch 50/50
# 600/600 [==============================] - 6s 9ms/step - loss: 0.0380

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
encoder.save('/content/gdrive/My Drive/VAE_with_descriminator_encoder.hd5', save_format='h5')
decoder.save('/content/gdrive/My Drive/VAE_with_descriminator_decoder.hd5', save_format='h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# !ls -lh '/content/gdrive/My Drive/VAE_with_descriminator_encoder.hd5'
# !ls -lh '/content/gdrive/My Drive/VAE_with_descriminator_decoder.hd5'
# Out:
# -rw------- 1 root root 414K Jun 30 21:35 '/content/gdrive/My Drive/VAE_with_descriminator_encoder.hd5'
# -rw------- 1 root root 407K Jun 30 21:35 '/content/gdrive/My Drive/VAE_with_descriminator_decoder.hd5'
